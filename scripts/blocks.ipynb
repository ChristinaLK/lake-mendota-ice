# %%
from ipythonblocks import BlockGrid
import math
import pandas
from datetime import datetime

# %%
infile = '../data/ice-dates.csv'

data = pandas.read_csv(infile, usecols = ["YEAR1","CLOSEDDATE","OPENEDDATE"], 
                      parse_dates = ["CLOSEDDATE","OPENEDDATE"])

# %%
marker_month = "11"
marker_day = "20"

for state in ["CLOSED","OPENED"]:
    data[state+'OFFSET'] = data.apply(lambda x: x[state+'DATE'] - datetime.strptime(str(x['YEAR1'])+"-"+marker_month+"-"+marker_day,'%Y-%m-%d'), axis = 1)
    data[state+'NORMOFFSET'] = data.apply(lambda x: math.floor(x[state+'OFFSET'].total_seconds() / (60 * 60 * 24) / 3), axis = 1)

# %%
#data.head(20)

# %%
start_yr = int(data['YEAR1'].min())
end_yr = int(data['YEAR1'].max())

# %%
height = end_yr - start_yr

# %%
delta_min = data['CLOSEDNORMOFFSET'].min()
delta_max = data['OPENEDNORMOFFSET'].max()

# %%
width = delta_max - delta_min

# %%
print(width, height)
# Out:
# 54 164

# %%
bg_color = (0, 0, 225)
padding = 2

grid = BlockGrid(width + padding, height + padding, fill=bg_color, block_size=5)

# %%
#tmp_color = (5,5,5)
#grid[:, 5:15] = tmp_color
#grid[:, 25:34] = tmp_color
#grid[:, 44:] = tmp_color

# %%
ice_color = (250, 250, 250)

for i in data.index:
    row_num = int(data.iloc[i]["YEAR1"] - start_yr)
    start = int(data.iloc[i]["CLOSEDNORMOFFSET"])
    end = int(data.iloc[i]["OPENEDNORMOFFSET"])
    grid[row_num, start:end] = ice_color
    #print(row_num, start, end)

# %%
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksb0b3c248-6358-4ba8-a8bf-d9e1a3241214 td {border: 1px solid white;}</style><table id="blocksb0b3c248-6358-4ba8-a8bf-d9e1a3241214" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 9]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 10]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 11]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 12]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 13]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 14]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 15]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 16]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 17]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 18]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 19]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 20]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 21]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 22]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 23]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 24]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 25]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 26]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 27]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 28]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 29]&#10;Color: (250, 250, 250)" style=" ...

# %%
bg_color = (0, 0, 225)
padding = 2

grid2 = BlockGrid(width + padding, (height*2) + padding, fill=bg_color, block_size=5)
ice_color = (250, 250, 250)

for i in data.index:
    row_num = int(data.iloc[i]["YEAR1"] - start_yr)*2
    start = int(data.iloc[i]["CLOSEDNORMOFFSET"])
    end = int(data.iloc[i]["OPENEDNORMOFFSET"])
    grid2[row_num, start:end] = ice_color
    #print(row_num, start, end)

# %%
lt_blue = (209, 237, 242)

grid2[1::2,:] = lt_blue

# %%
grid2
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksdb42b4ce-538a-4c02-93c6-004b0d03ea7f td {border: 1px solid white;}</style><table id="blocksdb42b4ce-538a-4c02-93c6-004b0d03ea7f" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 225)" style="width: 5px; height: 5px;background-color: rgb(0, 0, 225);"></td><td title="Index: [0, 9]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 10]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 11]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 12]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 13]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 14]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 15]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 16]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 17]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 18]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 19]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 20]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 21]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 22]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 23]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 24]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 25]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 26]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 27]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 28]&#10;Color: (250, 250, 250)" style="width: 5px; height: 5px;background-color: rgb(250, 250, 250);"></td><td title="Index: [0, 29]&#10;Color: (250, 250, 250)" style=" ...

# %%
height / width
# Out:
# 3.037037037037037

# %%
height*2 / width
# Out:
# 6.074074074074074
